# %% [markdown]
# # Cloning and Processing repos from GitHub

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from tqdm import tqdm

pd.options.display.float_format = "{:.2f}".format

# %% [markdown]
# ## Clone the repos from the filtered repos.

# %%
import pandas as pd
import git
from pathlib import Path
import os
from tqdm import tqdm
import json
from pydriller import Repository, ModificationType

# %% [markdown]
# ## Read repo names.

# %%
filtered_df = pd.read_json("./metadata/filtered_ghs_results_05_mar_2023.jsonl", orient="records", lines=True)

filtered_df = filtered_df[filtered_df['mainLanguage']=='Java']

# %%
import calendar
import time
import datetime
import logging
import jsonlines
import os
import shutil

logger = logging.getLogger("clone_repo")
fh = logging.FileHandler("./logs/clone_repo.log")
fh.setLevel(logging.DEBUG)
fh.setFormatter(logging.Formatter("%(asctime)s | %(levelname)s | %(message)s"))
logger.addHandler(fh)

#langs = ['Java', 'Python', 'TypeScript', 'JavaScript']
langs = ['Java']

# %%
github_metadata_path = "./metadata/cloned_repo_metadata.jsonl"

names = filtered_df["name"].tolist()

mainLanguages = filtered_df["mainLanguage"].tolist()

if os.path.exists(github_metadata_path):
    with jsonlines.open(github_metadata_path, "r") as reader:
        processed_names = set(line["name"] for line in reader)
    logger.info(f"Already processed {len(processed_names)} repositories!")
    names = [name for name in names if name not in processed_names]
    mainLanguages = [lang for name, lang in zip(names, mainLanguages) if name not in processed_names]
    logger.info(f"{len(names)} repositories left!")
else:
    open(github_metadata_path, "w").close()

names = names[2:4]

names
# Out:
# ['alipay/fury', 'aress31/burpgpt']

# %%
# cur_chunk = []
# chunksize = 20
#
# output_path = '../data/repos/'
#
# for lang in langs:
#     Path(output_path + lang).mkdir(parents=True, exist_ok=True)
#
# for id, repo_name in tqdm(enumerate(names), total=len(names)):
#     try:
#         lang = mainLanguages[id]
#         url = f'https://github.com/{repo_name}.git'
#         logger.info(f'Cloning repository at {url}.')
#         local_path = os.path.join(output_path + lang, repo_name.replace("/", "@"))
#
#         if os.path.exists(local_path):
#             logger.info(f"{local_path} already exists. remove!!!")
#             shutil.rmtree(local_path)
#
#         r = git.Repo.clone_from(url, local_path)
#         sha = r.rev_parse('HEAD').hexsha
#         data = {
#             "name": repo_name,
#             "mainLanguage": lang,
#             "url": url,
#             "local_path": local_path,
#             "sha": sha
#         }
#     except Exception as e:
#         print(e)
#         logger.warning(f"GitHub exception with repo {repo_name}, {repr(e)}")
#         data = {"name": repo_name, "mainLanguage": lang, "url": url, "local_path": None, "sha": None}
#
#     cur_chunk.append(data)
#     if len(cur_chunk) > chunksize:
#         with jsonlines.open(github_metadata_path, "a") as writer:
#             writer.write_all(cur_chunk)
#             cur_chunk = []
#
# if cur_chunk:
#     with jsonlines.open(github_metadata_path, "a") as writer:
#         writer.write_all(cur_chunk)
#         cur_chunk = []
# Out:
# 100%|██████████| 2/2 [00:08<00:00,  4.06s/it]

# %% [markdown]
# Merge with searched Data.

# %%
github_metadata_path = "./metadata/cloned_repo_metadata.jsonl"

github_metadata = pd.read_json(github_metadata_path, orient="records", lines=True)
github_metadata
# Out:
#               name mainLanguage                                     url  \
# 0      alipay/fury         Java      https://github.com/alipay/fury.git
# 1  aress31/burpgpt         Java  https://github.com/aress31/burpgpt.git
#
#                            local_path  \
# 0      ../data/repos/Java/alipay@fury
# 1  ../data/repos/Java/aress31@burpgpt
#
#                                         sha
# 0  20a1a78b17a75a123a6f5b7094c06ff77defc0fe
# 1  79ea6b9fe66b351f108191e2a0732147091060c1

# %% [markdown]
# 过滤出clone失败的项目，None error

# %%
github_metadata.loc[github_metadata.local_path.isnull()]
# Out:
# Empty DataFrame
# Columns: [name, mainLanguage, url, local_path, sha]
# Index: []

# %%
filtered_df = pd.read_json("./metadata/filtered_ghs_results_05_mar_2023.jsonl", orient="records", lines=True)

filtered_df = filtered_df.merge(github_metadata, on="name", how="inner")

#ghs_df[['mainLanguage_y', 'mainLanguage_x']]
filtered_df = filtered_df.loc[~filtered_df.local_path.isna()]
filtered_df.groupby("mainLanguage_y").agg(num_repos=("name", "count"), num_commits=("commits", "mean"))
# Out:
#                 num_repos  num_commits
# mainLanguage_y
# Java                    2       326.50

# %% [markdown]
# ## Mining all *added method* commits in each repo.

# %%
logger = logging.getLogger("commit_miner")
logger.setLevel(logging.DEBUG)
fh = logging.FileHandler("./logs/commit_miner.log")
fh.setLevel(logging.DEBUG)
fh.setFormatter(logging.Formatter("%(asctime)s | %(levelname)s | %(message)s"))
logger.addHandler(fh)

# %% [markdown]
# ## 存储repo的commit信息

# %%
from utils import download_all_commits
from call_parser import langs

github_metadata_path = "./metadata/cloned_repo_metadata.jsonl"
github_metadata = pd.read_json(github_metadata_path, orient="records", lines=True)
github_metadata = github_metadata.loc[~github_metadata.local_path.isna()]

commit_meta_path = "./metadata/repo_commit_metadata.jsonl"

processed_names = set()
if os.path.exists(commit_meta_path):
    with jsonlines.open(commit_meta_path, "r") as reader:
        processed_names = set(line["name"] for line in reader)
    logger.info(f"Already processed {len(processed_names)} repositories!")
    print(f"Already processed {len(processed_names)} repositories!")
else:
    open(commit_meta_path, "w").close()
# Out:
# /Users/tangze/miniconda3/envs/torch/lib/python3.10/site-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)

# %% [markdown]
# make dir to save the commit histories.

# %%
output_path = "../data/commits/"

for lang in ["Java", "Python", "JavaScript", "TypeScript"]:
    cur_output_path = output_path + lang + "/"
    Path(cur_output_path).mkdir(parents=True, exist_ok=True)

# %%
langs
# Out:
# {'Java': <build.java_call_parser.JavaCallParser at 0x142ba1cc0>,
#  'Python': <build.py_call_parser.PyCallParser at 0x142ba1cf0>,
#  'JavaScript': <build.js_call_parser.JSCallParser at 0x142ba1f60>,
#  'TypeScript': <build.ts_call_parser.TSCallParser at 0x142c37460>}

# %% [markdown]
# ### ！！！Only Keep repos which contains [20-500] methods.

# %%
cur_chunk = []
chunksize = 20

bar = tqdm(github_metadata.itertuples(), total=len(github_metadata) - len(processed_names))
for row in bar:
    name = getattr(row, 'name')
    lang = getattr(row, 'mainLanguage')
    local_path = getattr(row, 'local_path')
    url = getattr(row, 'url')
    sha = getattr(row, 'sha')

    if name in processed_names:
        logger.info(f"{name} has been processed, skip.")
        continue

    try:
        extension = langs[lang].extension
        cur_commit_files_path = output_path + lang + "/" + name.replace("/", "@") + "_commits/"
        Path(cur_commit_files_path).mkdir(parents=True, exist_ok=True)
        
        result = download_all_commits(local_path, extension, bar=bar, output_path=cur_commit_files_path)
        if result is None:
            continue

        cur_output_path = output_path + lang + "/" + name.replace("/", "@") + "_commits.jsonl"  
            
        data = {
            "name": name,
            "mainLanguage": lang,
            "url": url,
            "local_path": local_path,
            "sha": sha,
            "commit_path": cur_output_path,
            "commit_file_path": cur_commit_files_path,
            "num_methods": len(result)
        }
    except Exception as e:
        print(e)
        logger.warning(f"GitHub exception with repo {name}, {repr(e)}")
        result = None
        data = {"name": name, "mainLanguage": lang, "url": url, "local_path": local_path, "sha": sha, 
                "commit_path": None, "commit_file_path": None, "num_methods": None}

    if result is not None:
        with jsonlines.open(cur_output_path, "w") as writer:
            writer.write_all(result)
    
    cur_chunk.append(data)
    if len(cur_chunk) > chunksize:
        with jsonlines.open(commit_meta_path, "a") as writer:
            writer.write_all(cur_chunk)
            cur_chunk = []

if cur_chunk:
    with jsonlines.open(commit_meta_path, "a") as writer:
        writer.write_all(cur_chunk)
        cur_chunk = []
# Out:
# Deal with .java: process repo aress31@burpgpt at commit 075d, processed : 100%|██████████| 2/2 [00:48<00:00, 24.05s/it]

# %%
from build_data import build_dataset

build_dataset(prefix_path='/home/tangze-U2315/project-method-miner/data/',
              process_lang="Java",
              stack_graph_path='/home/tangze-U2315/stack-graphs/target/debug/')
# Out:
#                                                  name mainLanguage  \
# 0                                         alipay/fury         Java
# 1                                       baidu/bifromq         Java
# 2                                      google/bindiff         Java
# 3                               LangStream/langstream         Java
# 4                                      cubefs/compass         Java
# 5                           sofastack/sofa-serverless         Java
# 6                                   aizuda/easy-retry         Java
# 7                                 knowly-ai/langtorch         Java
# 8                                       dromara/sms4j         Java
# 9                               zongzibinbin/mallchat         Java
# 10                              badlogic/heissepreise   JavaScript
# 11                                    jason5ng32/MyIP   JavaScript
# 12                                smallcloudai/refact   JavaScript
# 13                        lllllllillllllillll/DweebUI   JavaScript
# 14                                    instant-dev/api   JavaScript
# 15                             cyfershepard/jellystat   JavaScript
# 16                             williamtroup/Syntax.js   JavaScript
# 17                   liberty-liu/everright-formeditor   JavaScript
# 18                               viarotel-org/escrcpy   JavaScript
# 19                                      replicate/zoo   JavaScript
# 20                      Significant-Gravitas/Auto-GPT       Python
# 21                                 gventuri/pandas-ai       Python
# 22                        TransformerOptimus/SuperAGI       Python
# 23                                  aiwaves-cn/agents       Python
# 24                   chatchat-space/langchain-ChatGLM       Python
# 25                              vision-cair/minigpt-4       Python
# 26                                zilliztech/GPTCache       Python
# 27  rvc-project/retrieval-based-voice-conversion-w...       Python
# 28                                     OpenBMB/XAgent       Python
# 29                                     camel-ai/camel       Python
# 30                              orillusion/orillusion   TypeScript
# 31                                    kuma-ui/kuma-ui   TypeScript
# 32                         aprilnea/chatgpt-admin-web   TypeScript
# 33                                 a16z-infra/ai-town   TypeScript
# 34                                      antfu/shikiji   TypeScript
# 35                                ikun-svelte/ikun-ui   TypeScript
# 36                                    pezzolabs/pezzo   TypeScript
# 37                webfansplz/vite-plugin-vue-devtools   TypeScript
# 38                                  miurla/babyagi-ui   TypeScript
# 39                             erictik/midjourney-api   TypeScript
#
#                                                   url  \
# 0                  https://github.com/alipay/fury.git
# 1                https://github.com/baidu/bifromq.git
# 2               https://github.com/google/bindiff.git
# 3        https://github.com/LangStream/langstream.git
# 4               https://github.com/cubefs/compass.git
# 5    https://github.com/sofastack/sofa-serverless.git
# 6            https://github.com/aizuda/easy-retry.git
# 7          https://github.com/knowly-ai/langtorch.git
# 8                https://github.com/dromara/sms4j.git
# 9        https://github.com/zongzibinbin/mallchat.git
# 10       https://github.com/badlogic/heissepreise.git
# 11             https://github.com/jason5ng32/MyIP.git
# 12         https://github.com/smallcloudai/refact.git
# 13  https://github.com/lllllllillllllillll/DweebUI...
# 14             https://github.com/instant-dev/api.git
# 15      https://github.com/cyfershepard/jellystat.git
# 16      https://github.com/williamtroup/Syntax.js.git
# 17  https://github.com/liberty-liu/everright-forme...
# 18        https://github.com/viarotel-org/escrcpy.git
# 19               https://github.com/replicate/zoo.git
# 20  https://github.com/Significant-Gravitas/Auto-G...
# 21          https://github.com/gventuri/pandas-ai.git
# 22  https://github.com/TransformerOptimus/SuperAGI...
# 23           https://github.com/aiwaves-cn/agents.git
# 24  https://github.com/chatchat-space/langchain-Ch...
# 25       https://github.com/vision-cair/minigpt-4.git
# 26         https://github.com/zilliztech/GPTCache.git
# 27  https://github.com/rvc-project/retrieval-based...
# 28              https://github.com/OpenBMB/XAgent.git
# 29              https://github.com/camel-ai/camel.git
# 30       https://github.com/orillusion/orillusion.git
# 31             https://github.com/kuma-ui/kuma-ui.git
# 32  https://github.com/aprilnea/chatgpt-admin-web.git
# 33          https://github.com/a16z-infra/ai-town.git
# 34               https://github.com/antfu/shikiji.git
# 35         https://github.com/ikun-svelte/ikun-ui.git
# 36             https://github.com/pezzolabs/pezzo.git
# 37  https://github.com/webfansplz/vite-plugin-vue-...
# 38           https://github.com/miurla/babyagi-ui.git
# 39      https://github.com/erictik/midjourney-api.git
#
#                                            local_path  \
# 0                      ../data/repos/Java/alipay@fury
# 1                    ../data/repos/Java/baidu@bifromq
# 2                   ../data/repos/Java/google@bindiff
# 3            ../data/repos/Java/LangStream@langstream
# 4                   ../data/repos/Java/cubefs@compass
# 5        ../data/repos/Java/sofastack@sofa-serverless
# 6                ../data/repos/Java/aizuda@easy-retry
# 7              ../data/repos/Java/knowly-ai@langtorch
# 8                    ../data/repos/Java/dromara@sms4j
# 9            ../data/repos/Java/zongzibinbin@mallchat
# 10     ../data/repos/JavaScript/badlogic@heissepreise
# 11           ../data/repos/JavaScript/jason5ng32@MyIP
# 12       ../data/repos/JavaScript/smallcloudai@refact
# 13  ../data/repos/JavaScript/lllllllillllllillll@D...
# 14           ../data/repos/JavaScript/instant-dev@api
# 15    ../data/repos/JavaScript/cyfershepard@jellystat
# 16    ../data/repos/JavaScript/williamtroup@Syntax.js
# 17  ../data/repos/JavaScript/liberty-liu@everright...
# 18      ../data/repos/JavaScript/viarotel-org@escrcpy
# 19             ../data/repos/JavaScript/replicate@zoo
# 20  ../data/repos/Python/Significant-Gravitas@Auto...
# 21            ../data/repos/Python/gventuri@pandas-ai
# 22   ../data/repos/Python/TransformerOptimus@SuperAGI
# 23             ../data/repos/Python/aiwaves-cn@agents
# 24  ../data/repos/Python/chatchat-space@langchain-...
# 25         ../data/repos/Python/vision-cair@minigpt-4
# 26           ../data/repos/Python/zilliztech@GPTCache
# 27  ../data/repos/Python/rvc-project@retrieval-bas...
# 28                ../data/repos/Python/OpenBMB@XAgent
# 29                ../data/repos/Python/camel-ai@camel
# 30     ../data/repos/TypeScript/orillusion@orillusion
# 31           ../data/repos/TypeScript/kuma-ui@kuma-ui
# 32  ../data/repos/TypeScript/aprilnea@chatgpt-admi...
# 33        ../data/repos/TypeScript/a16z-infra@ai-town
# 34             ../data/repos/TypeScript/antfu@shikiji
# 35       ../data/repos/TypeScript/ikun-svelte@ikun-ui
# 36           ../data/repos/TypeScript/pezzolabs@pezzo
# 37  ../data/repos/TypeScript/webfansplz@vite-plugi...
# 38         ../data/repos/TypeScript/miurla@babyagi-ui
# 39    ../data/repos/TypeScript/erictik@midjourney-api
#
#                                          sha  \
# 0   0437556ef4f3445869923f6b90806f565fda0e33
# 1   8c3b21dbdb3bc34cac963d714669f50d2ffa9c6e
# 2   0a4526289e5a267d9c8f0f76a1f5dd21d691e808
# 3   979303b777d59b2910c32372b6e71a60486116e7
# 4   d4b53de98d66a4771660efd80cf298903aa7f48e
# 5   de5709580d6b9e9a5f4bde0e514806e44f949914
# 6   86ae31421e6add1c75324dbab9400fa31cd0f120
# 7   9809e32eca257465d28c390b2cf140bbffca697a
# 8   893b35371e286485420c7ffe22fba075a3855a55
# 9   f2563328d4a5311a2308079025da4e637437759b
# 10  f2d9939adf6ed1cfc5a40019a5b987a568f45165
# 11  5655b6dd93a4c89fce3505651ba96d980a6f6b4e
# 12  90c217c0d51ded3d6d34114bc52a780fe6303ec6
# 13  c7d79b296cb6cff140aad346c91da327f3188bd4
# 14  a3c0a2ef3d9e36ed439ea23488fd346a33b9f498
# 15  ccc4cef70d5bee9cd1c339c23a68f42f7f1a7ca9
# 16  63f9ad4474395dfd89da74f0d80e9fd07b789665
# 17  d9eefddc91586100512c9c648a6cf896e9e14fd5
# 18  39bfd02cc4428895c9652552b46569bd6bdd6ec8
# 19  772ae3aa0ce67466d94f97b6d3a14a8b63b12419
# 20  fea62a77bc3072c3570ab16e050a1b032e0154da
# 21  7f11f1807266a28b96cb9792fbe599f56f503c52
# 22  eb94dcbf81bcab2137c8fbe6e6b1a861e55f8286
# 23  350246d926c41728610fba73b7703c9d65b20567
# 24  d879e86cabeb2e6b7e1ea754efb539c6856940ab
# 25  71df7647b664e20f6e209e75dc8189105e6950e2
# 26  acc20f05400dabdcde451194e9bb73b986747685
# 27  7728caad546c8d5dab17e724b41fbe9b28edaf30
# 28  3619c25855f878481ddb893709c1e30d76aff794
# 29  9c0f5987d7c07e2cd59361b6e3a4583c8cfcc482
# 30  49ad63a0e903bb23804386defa7bc2abaa4a3be5
# 31  8605c61060d2b05f4ae3b65129ae52f5a4425c9f
# 32  c6c5a1ca21ff3cdb30195e39315d4cb8cf4aab28
# 33  86f1275eecf6832d0236e8f429af7c635a0a48ad
# 34  fc923646e2a450e8d929598ea99d9fed96cbb657
# 35  2cb7856a155eb9db5eaf2be689de391503869ee1
# 36  da1c9135a2676a36df9cbecd99f634ad19ae2b05
# 37  da8f7bd4ce1eac1c9f1079cd591a9ac589152751
# 38  e2ad6385cfbc3e72816d5bce44f1ecb5bcd0b78a
# 39  1346be21baa852938e5eaed4329bf72f2c45e8aa
#
#                                           commit_path  \
# 0      ../data/commits/Java/alipay@fury_commits.jsonl
# 1    ../data/commits/Java/baidu@bifromq_commits.jsonl
# 2   ../data/commits/Java/google@bindiff_commits.jsonl
# 3   ../data/commits/Java/LangStream@langstream_com...
# 4   ../data/commits/Java/cubefs@compass_commits.jsonl
# 5   ../data/commits/Java/sofastack@sofa-serverless...
# 6   ../data/commits/Java/aizuda@easy-retry_commits...
# 7   ../data/commits/Java/knowly-ai@langtorch_commi...
# 8    ../data/commits/Java/dromara@sms4j_commits.jsonl
# 9   ../data/commits/Java/zongzibinbin@mallchat_com...
# 10  ../data/commits/JavaScript/badlogic@heisseprei...
# 11  ../data/commits/JavaScript/jason5ng32@MyIP_com...
# 12  ../data/commits/JavaScript/smallcloudai@refact...
# 13  ../data/commits/JavaScript/lllllllillllllillll...
# 14  ../data/commits/JavaScript/instant-dev@api_com...
# 15  ../data/commits/JavaScript/cyfershepard@jellys...
# 16  ../data/commits/JavaScript/williamtroup@Syntax...
# 17  ../data/commits/JavaScript/liberty-liu@everrig...
# 18  ../data/commits/JavaScript/viarotel-org@escrcp...
# 19  ../data/commits/JavaScript/replicate@zoo_commi...
# 20  ../data/commits/Python/Significant-Gravitas@Au...
# 21  ../data/commits/Python/gventuri@pandas-ai_comm...
# 22  ../data/commits/Python/TransformerOptimus@Supe...
# 23  ../data/commits/Python/aiwaves-cn@agents_commi...
# 24  ../data/commits/Python/chatchat-space@langchai...
# 25  ../data/commits/Python/vision-cair@minigpt-4_c...
# 26  ../data/commits/Python/zilliztech@GPTCache_com...
# 27  ../data/commits/Python/rvc-project@retrieval-b...
# 28  ../data/commits/Python/OpenBMB@XAgent_commits....
# 29  ../data/commits/Python/camel-ai@camel_commits....
# 30  ../data/commits/TypeScript/orillusion@orillusi...
# 31  ../data/commits/TypeScript/kuma-ui@kuma-ui_com...
# 32  ../data/commits/TypeScript/aprilnea@chatgpt-ad...
# 33  ../data/commits/TypeScript/a16z-infra@ai-town_...
# 34  ../data/commits/TypeScript/antfu@shikiji_commi...
# 35  ../data/commits/TypeScript/ikun-svelte@ikun-ui...
# 36  ../data/commits/TypeScript/pezzolabs@pezzo_com...
# 37  ../data/commits/TypeScript/webfansplz@vite-plu...
# 38  ../data/commits/TypeScript/miurla@babyagi-ui_c...
# 39  ../data/commits/TypeScript/erictik@midjourney-...
#
#                                      commit_file_path  num_methods
# 0           ../data/commits/Java/alipay@fury_commits/        10533
# 1         ../data/commits/Java/baidu@bifromq_commits/        10495
# 2        ../data/commits/Java/google@bindiff_commits/         7090
# 3   ../data/commits/Java/LangStream@langstream_com...         5889
# 4        ../data/commits/Java/cubefs@compass_commits/         5252
# 5   ../data/commits/Java/sofastack@sofa-serverless...         3221
# 6     ../data/commits/Java/aizuda@easy-retry_commits/         2802
# 7   ../data/commits/Java/knowly-ai@langtorch_commits/         1551
# 8         ../data/commits/Java/dromara@sms4j_commits/         1442
# 9   ../data/commits/Java/zongzibinbin@mallchat_com...         1260
# 10  ../data/commits/JavaScript/badlogic@heisseprei...         5152
# 11  ../data/commits/JavaScript/jason5ng32@MyIP_com...         3098
# 12  ../data/commits/JavaScript/smallcloudai@refact...         2451
# 13  ../data/commits/JavaScript/lllllllillllllillll...         2448
# 14  ../data/commits/JavaScript/instant-dev@api_com...         2305
# 15  ../data/commits/JavaScript/cyfershepard@jellys...         1264
# 16  ../data/commits/JavaScript/williamtroup@Syntax...         1141
# 17  ../data/commits/JavaScript/liberty-liu@everrig...          629
# 18  ../data/commits/JavaScript/viarotel-org@escrcp...          345
# 19  ../data/commits/JavaScript/replicate@zoo_commits/          295
# 20  ../data/commits/Python/Significant-Gravitas@Au...         5204
# 21  ../data/commits/Python/gventuri@pandas-ai_comm...         2986
# 22  ../data/commits/Python/TransformerOptimus@Supe...         2888
# 23  ../data/commits/Python/aiwaves-cn@agents_commits/         2789
# 24  ../data/commits/Python/chatchat-space@langchai...         2113
# 25  ../data/commits/Python/vision-cair@minigpt-4_c...         1994
# 26  ../data/commits/Python/zilliztech@GPTCache_com...         1476
# 27  ../data/commits/Python/rvc-project@retrieval-b...         1077
# 28     ../data/commits/Python/OpenBMB@XAgent_commits/         1055
# 29     ../data/commits/Python/camel-ai@camel_commits/         1023
# 30  ../data/commits/TypeScript/orillusion@orillusi...         4116
# 31  ../data/commits/TypeScript/kuma-ui@kuma-ui_com...         2711
# 32  ../data/commits/TypeScript/aprilnea@chatgpt-ad...         1722
# 33  ../data/commits/TypeScript/a16z-infra@ai-town_...         1300
# 34  ../data/commits/TypeScript/antfu@shikiji_commits/         1173
# 35  ../data/commits/TypeScript/ikun-svelte@ikun-ui...         1158
# 36  ../data/commits/TypeScript/pezzolabs@pezzo_com...          760
# 37  ../data/commits/TypeScript/webfansplz@vite-plu...          625
# 38  ../data/commits/TypeScript/miurla@babyagi-ui_c...          564
# 39  ../data/commits/TypeScript/erictik@midjourney-...          448
